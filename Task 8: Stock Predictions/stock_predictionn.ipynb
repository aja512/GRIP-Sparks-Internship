# %% [markdown]
# # Task 9: Stock Market Prediction using Numerical and Textual Analysis
# ### Author: Amanda J Andrade.
# Copyright Amanda J Andrade, 2022
#
# **Not for distribution.**
#
# Create a hybrid model for stock price or performance prediction using numerical analysis of historical stock prices, and sentimental analysis of news headlines. The stock to analyze and predict is SENSEX (S&P BSE SENSEX)

# %% [markdown]
# ## Import the Libraries

# %%
# Import the libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')


from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

import nltk
import re
from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
import xgboost
import lightgbm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/d1/0b_ckbv94b76520jr7j7ydzw0000gn/T/ipykernel_13346/1132316586.py in <module>
#      23 from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
#      24 from sklearn.tree import DecisionTreeRegressor
# ---> 25 import xgboost
#      26 import lightgbm
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# For reading stock data from yahoo
from pandas_datareader.data import DataReader
# For time stamps
from datetime import datetime

# %%
# Load the first dataset
columns=['Date','Category','News']
ndf = pd.read_csv("india-news-headlines.csv",names=columns)

# %%
print('Showing part of the whole dataset:')
ndf.head(5)
# Out:
# Showing part of the whole dataset:
#            Date           Category  \
# 0  publish_date  headline_category
# 1      20010102            unknown
# 2      20010102            unknown
# 3      20010102            unknown
# 4      20010102            unknown
#
#                                                 News
# 0                                      headline_text
# 1  Status quo will not be disturbed at Ayodhya; s...
# 2                Fissures in Hurriyat over Pak visit
# 3              America's unwanted heading for India?
# 4                 For bigwigs; it is destination Goa

# %%
ndf.drop(0, inplace=True)
ndf.drop('Category', axis = 1, inplace=True)
print('Showing part of the whole dataset:')
ndf.head(-5)
# Out:
# Showing part of the whole dataset:
#              Date                                               News
# 1        20010102  Status quo will not be disturbed at Ayodhya; s...
# 2        20010102                Fissures in Hurriyat over Pak visit
# 3        20010102              America's unwanted heading for India?
# 4        20010102                 For bigwigs; it is destination Goa
# 5        20010102               Extra buses to clear tourist traffic
# ...           ...                                                ...
# 3424058  20201231        50 NRIs reach Singhu; offer help to farmers
# 3424059  20201231  Navjot Singh Sidhu tweets apology; says 'wore ...
# 3424060  20201231  Azim Premji organisation's name misused to che...
# 3424061  20201231    Get govt nod to probe officials: MP to agencies
# 3424062  20201231  Peddler nabbed; 10kg ganja seized in Anantapur...
#
# [3424062 rows x 2 columns]

# %%
# Load the second dataset
hisdf = pd.read_csv("BSEEN.csv")
hisdf.head(-5)
# Out:
#            Date          Open          High           Low         Close  \
# 0    2019-12-17  41052.359375  41401.648438  41005.179688  41352.171875
# 1    2019-12-18  41442.750000  41614.769531  41358.468750  41558.570313
# 2    2019-12-19  41571.820313  41719.289063  41456.398438  41673.921875
# 3    2019-12-20  41746.199219  41809.960938  41636.109375  41681.539063
# 4    2019-12-23  41548.261719  41701.621094  41474.609375  41642.660156
# ..          ...           ...           ...           ...           ...
# 242  2020-12-04  44665.910156  45148.281250  44665.910156  45079.550781
# 243  2020-12-07  45099.921875  45458.921875  45024.468750  45426.968750
# 244  2020-12-08  45568.800781  45742.230469  45335.171875  45608.511719
# 245  2020-12-09  45891.039063  46164.101563  45792.011719  46103.500000
# 246  2020-12-10  45999.421875  46043.968750  45685.871094  45959.878906
#
#         Adj Close   Volume
# 0    41352.171875  19000.0
# 1    41558.570313  24300.0
# 2    41673.921875  33300.0
# 3    41681.539063  33600.0
# 4    41642.660156   6200.0
# ..            ...      ...
# 242  45079.550781  27600.0
# 243  45426.968750  18700.0
# 244  45608.511719  18200.0
# 245  46103.500000  20700.0
# 246  45959.878906  12700.0
#
# [247 rows x 7 columns]

# %% [markdown]
# ## Common Dataset Exploration

# %%
# Check for common information of the first datast
ndf["Date"] = pd.to_datetime(ndf["Date"],format='%Y%m%d')
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3424067 entries, 1 to 3424067
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Date    datetime64[ns]
#  1   News    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 78.4+ MB

# %%
# Group the headlines for each day
ndf['News'] = ndf.groupby(['Date']).transform(lambda x : ' '.join(x)) 
ndf = ndf.drop_duplicates() 
ndf.reset_index(inplace=True,drop=True)

# %%
ndf
# Out:
#            Date                                               News
# 0    2001-01-02  Status quo will not be disturbed at Ayodhya; s...
# 1    2001-01-03  Powerless north India gropes in the dark Think...
# 2    2001-01-04  The string that pulled Stephen Hawking to Indi...
# 3    2001-01-05  Light combat craft takes India into club class...
# 4    2001-01-06  Light combat craft takes India into club class...
# ...         ...                                                ...
# 7257 2020-12-27  #BigInterview! Dhritiman Chatterjee: Nobody da...
# 7258 2020-12-28  Horoscope Today; 28 December 2020: Check astro...
# 7259 2020-12-29  Man recovers charred remains of 'thief' from h...
# 7260 2020-12-30  Numerology Readings 30 December 2020: Predicti...
# 7261 2020-12-31  Horoscope Today; 31 December 2020: Check astro...
#
# [7262 rows x 2 columns]

# %%
# Check for any duplicated values
ndf.isnull().sum()
# Out:
# Date    0
# News    0
# dtype: int64

# %%
len(ndf)
# Out:
# 7262

# %%
hisdf=hisdf[["Date","Open","High","Low","Close","Volume"]]
hisdf.head(-5)
# Out:
#            Date          Open          High           Low         Close  \
# 0    2019-12-17  41052.359375  41401.648438  41005.179688  41352.171875
# 1    2019-12-18  41442.750000  41614.769531  41358.468750  41558.570313
# 2    2019-12-19  41571.820313  41719.289063  41456.398438  41673.921875
# 3    2019-12-20  41746.199219  41809.960938  41636.109375  41681.539063
# 4    2019-12-23  41548.261719  41701.621094  41474.609375  41642.660156
# ..          ...           ...           ...           ...           ...
# 242  2020-12-04  44665.910156  45148.281250  44665.910156  45079.550781
# 243  2020-12-07  45099.921875  45458.921875  45024.468750  45426.968750
# 244  2020-12-08  45568.800781  45742.230469  45335.171875  45608.511719
# 245  2020-12-09  45891.039063  46164.101563  45792.011719  46103.500000
# 246  2020-12-10  45999.421875  46043.968750  45685.871094  45959.878906
#
#       Volume
# 0    19000.0
# 1    24300.0
# 2    33300.0
# 3    33600.0
# 4     6200.0
# ..       ...
# 242  27600.0
# 243  18700.0
# 244  18200.0
# 245  20700.0
# 246  12700.0
#
# [247 rows x 6 columns]

# %%
# Check for common information of the second dataset
hisdf["Date"]= pd.to_datetime(hisdf["Date"])
hisdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    252 non-null    datetime64[ns]
#  1   Open    250 non-null    float64
#  2   High    250 non-null    float64
#  3   Low     250 non-null    float64
#  4   Close   250 non-null    float64
#  5   Volume  250 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 11.9 KB

# %%
hisdf.describe()
# Out:
#                Open          High           Low         Close         Volume
# count    250.000000    250.000000    250.000000    250.000000     250.000000
# mean   37804.237375  38071.182859  37422.826992  37745.454117   19134.000000
# std     4507.985769   4380.974060   4647.212947   4535.304336   16540.261333
# min    26499.810547  27462.869141  25638.900391  25981.240234       0.000000
# 25%    34369.659179  34779.932618  33975.389648  34257.097656   13125.000000
# 50%    38489.480469  38750.359375  38234.869140  38425.974610   17000.000000
# 75%    41179.222656  41376.482422  41023.923828  41135.233399   21075.000000
# max    46774.320313  46992.570313  46627.601563  46890.339844  188300.000000

# %%
hisdf.isnull().sum()

# %%
len(hisdf)

# %%
# Figure plot
plt.figure(figsize=(20,10))
hisdf['Close'].plot()
plt.ylabel('BSESN')
# Out:
# Text(0, 0.5, 'BSESN')

# %% [markdown]
# ## Remove Unwanted Characters from the News

# %%
#removing unwanted characters from the News
ndf.replace("[^a-zA-Z']"," ",regex=True,inplace=True)
ndf["News"].head(5)
# Out:
# 0    Status quo will not be disturbed at Ayodhya  s...
# 1    Powerless north India gropes in the dark Think...
# 2    The string that pulled Stephen Hawking to Indi...
# 3    Light combat craft takes India into club class...
# 4    Light combat craft takes India into club class...
# Name: News, dtype: object

# %% [markdown]
# ## Historical Analysis
# ### Plot the Moving Average

# %%
#Plotting moving average
close = hisdf['Close']

ma = close.rolling(window = 50).mean()
std = close.rolling(window = 50).std()

plt.figure(figsize=(20,10))
hisdf['Close'].plot(color='g',label='Close')
ma.plot(color = 'r',label='Rolling Mean')
std.plot(label = 'Rolling Standard Deviation')

plt.legend()

# %% [markdown]
# ### Plotting Returns

# %%
#Plotting returns
returns = close / close.shift(1) - 1

plt.figure(figsize = (20,10))
returns.plot(label='Return', color = 'g')
plt.title("Returns")
# Out:
# Text(0.5, 1.0, 'Returns')

# %%
# Train test split
train = hisdf[:1219]
test = hisdf[1219:]

# %% [markdown]
# ### Rolling Mean and Standard Deviation

# %%
#Stationarity test
def test_stationarity(timeseries):

 #Determine the rolling statistics
 rolmean = timeseries.rolling(20).mean()
 rolstd = timeseries.rolling(20).std()

 #Plot rolling statistics:
 plt.figure(figsize = (20,10))
 plt.plot(timeseries, color = 'blue', label = 'original')
 plt.plot(rolmean, color = 'r', label = 'rolling mean')
 plt.plot(rolstd, color = 'black', label = 'rolling std')
 plt.xlabel('Date')
 plt.legend()
 plt.title('Rolling Mean and Standard Deviation',  fontsize = 30)
 plt.show(block = False)
 
 print('Results of dickey fuller test')
 result = adfuller(timeseries, autolag = 'AIC')
 labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
 for value,label in zip(result, labels):
   print(label+' : '+str(value) )
 if result[1] <= 0.05:
   print("Strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
 else:
   print("Weak evidence against null hypothesis, time series is non-stationary ")
test_stationarity(train['Close'])
# Out:
# Results of dickey fuller test
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d1/0b_ckbv94b76520jr7j7ydzw0000gn/T/ipykernel_13346/4042209653.py in <module>
#      25  else:
#      26    print("Weak evidence against null hypothesis, time series is non-stationary ")
# ---> 27 test_stationarity(train['Close'])
#
# /var/folders/d1/0b_ckbv94b76520jr7j7ydzw0000gn/T/ipykernel_13346/4042209653.py in test_stationarity(timeseries)
#      17
#      18  print('Results of dickey fuller test')
# ---> 19  result = adfuller(timeseries, autolag = 'AIC')
#      20  labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
#      21  for value,label in zip(result, labels):
#
# NameError: name 'adfuller' is not defined

# %%
train_log = np.log(train['Close']) 
test_log = np.log(test['Close'])

mav = train_log.rolling(24).mean() 
plt.figure(figsize = (20,10))
plt.plot(train_log) 
plt.plot(mav, color = 'red')

# %%
train_log.dropna(inplace = True)
test_log.dropna(inplace = True)

test_stationarity(train_log)
# Out:
# Results of dickey fuller test
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d1/0b_ckbv94b76520jr7j7ydzw0000gn/T/ipykernel_13346/3222250332.py in <module>
#       2 test_log.dropna(inplace = True)
#       3
# ----> 4 test_stationarity(train_log)
#
# /var/folders/d1/0b_ckbv94b76520jr7j7ydzw0000gn/T/ipykernel_13346/4042209653.py in test_stationarity(timeseries)
#      17
#      18  print('Results of dickey fuller test')
# ---> 19  result = adfuller(timeseries, autolag = 'AIC')
#      20  labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
#      21  for value,label in zip(result, labels):
#
# NameError: name 'adfuller' is not defined

# %%
train_log_diff = train_log - mav
train_log_diff.dropna(inplace = True)

test_stationarity(train_log_diff)
# Out:
# Results of dickey fuller test
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d1/0b_ckbv94b76520jr7j7ydzw0000gn/T/ipykernel_13346/1357657082.py in <module>
#       2 train_log_diff.dropna(inplace = True)
#       3
# ----> 4 test_stationarity(train_log_diff)
#
# /var/folders/d1/0b_ckbv94b76520jr7j7ydzw0000gn/T/ipykernel_13346/4042209653.py in test_stationarity(timeseries)
#      17
#      18  print('Results of dickey fuller test')
# ---> 19  result = adfuller(timeseries, autolag = 'AIC')
#      20  labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
#      21  for value,label in zip(result, labels):
#
# NameError: name 'adfuller' is not defined

# %%
#Using auto arima to make predictions using log data
from pmdarima import auto_arima

# %%
model = auto_arima(train_log, trace = True, error_action = 'ignore', suppress_warnings = True)
model.fit(train_log)
predictions = model.predict(periods = len(test))
predictions = pd.DataFrame(predictions,index = test_log.index,columns=['Prediction'])
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-1229.181, Time=0.39 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-1228.630, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-1231.551, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-1230.976, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-1230.477, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-1230.063, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-1229.768, Time=0.19 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-1232.318, Time=0.37 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-1228.479, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-1228.450, Time=0.20 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-1230.322, Time=0.06 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-1233.856, Time=0.55 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=-1226.381, Time=0.66 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-1240.592, Time=0.54 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-1233.147, Time=0.48 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=-1241.164, Time=0.64 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=-1254.688, Time=0.68 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=-1239.892, Time=0.57 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=-1253.495, Time=0.74 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=-1248.941, Time=0.71 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=-1257.043, Time=0.43 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=-1243.125, Time=0.39 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=-1243.992, Time=0.36 sec
#  ARIMA(5,1,4)(0,0,0)[0]             : AIC=-1256.479, Time=0.50 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=-1231.043, Time=0.33 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : AIC=-1250.844, Time=0.58 sec
#
# Best model:  ARIMA(5,1,3)(0,0,0)[0]
# Total fit time: 9.821 seconds
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/d1/0b_ckbv94b76520jr7j7ydzw0000gn/T/ipykernel_13346/1619001613.py in <module>
#       2 model.fit(train_log)
#       3 predictions = model.predict(periods = len(test))
# ----> 4 predictions = pd.DataFrame(predictions,index = test_log.index,columns=['Prediction'])
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     670                 )
#     671             else:
# --> 672                 mgr = ndarray_to_mgr(
#     673                     data,
#     674                     index,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (10, 1), indices imply (0, 1)

# %%
plt.plot(train_log, label='Train')
plt.plot(test_log, label='Test')
plt.plot(predictions, label='Prediction')
plt.title('BSESN Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Actual Stock Price')
# Out:
# Text(0, 0.5, 'Actual Stock Price')

# %% [markdown]
# ## Error Calculation

# %%
#Calculating error
rms = np.sqrt(mean_squared_error(test_log,predictions))
print("RMSE : ", rms)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/d1/0b_ckbv94b76520jr7j7ydzw0000gn/T/ipykernel_13346/2348272043.py in <module>
#       1 #Calculating error
# ----> 2 rms = np.sqrt(mean_squared_error(test_log,predictions))
#       3 print("RMSE : ", rms)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     421     0.825...
#     422     """
# --> 423     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     424         y_true, y_pred, multioutput
#     425     )
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      87         the dtype argument passed to check_array.
#      88     """
# ---> 89     check_consistent_length(y_true, y_pred)
#      90     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      91     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     329     uniques = np.unique(lengths)
#     330     if len(uniques) > 1:
# --> 331         raise ValueError(
#     332             "Found input variables with inconsistent numbers of samples: %r"
#     333             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [0, 10]

# %% [markdown]
# ## Textual Analysis

# %%
#Functions to get the subjectivity and polarity
def getSubjectivity(text):
  return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
  return  TextBlob(text).sentiment.polarity

# %%
#Adding subjectivity and polarity columns
ndf['Subjectivity'] = ndf['News'].apply(getSubjectivity)
ndf['Polarity'] = ndf['News'].apply(getPolarity)
ndf
# Out:
#            Date                                               News  \
# 0    2001-01-02  Status quo will not be disturbed at Ayodhya  s...
# 1    2001-01-03  Powerless north India gropes in the dark Think...
# 2    2001-01-04  The string that pulled Stephen Hawking to Indi...
# 3    2001-01-05  Light combat craft takes India into club class...
# 4    2001-01-06  Light combat craft takes India into club class...
# ...         ...                                                ...
# 7257 2020-12-27   BigInterview  Dhritiman Chatterjee  Nobody da...
# 7258 2020-12-28  Horoscope Today     December       Check astro...
# 7259 2020-12-29  Man recovers charred remains of 'thief' from h...
# 7260 2020-12-30  Numerology Readings    December       Predicti...
# 7261 2020-12-31  Horoscope Today     December       Check astro...
#
#       Subjectivity  Polarity
# 0         0.286859  0.143590
# 1         0.392857  0.089286
# 2         0.445360  0.093039
# 3         0.480553  0.264024
# 4         0.439394  0.248485
# ...            ...       ...
# 7257      0.392082  0.042978
# 7258      0.409973  0.071405
# 7259      0.415684  0.060775
# 7260      0.436863  0.046930
# 7261      0.408454  0.091829
#
# [7262 rows x 4 columns]

# %%
#Adding sentiment score to df_news
sia = SentimentIntensityAnalyzer()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /var/folders/d1/0b_ckbv94b76520jr7j7ydzw0000gn/T/ipykernel_13346/3661878534.py in <module>
#       1 #Adding sentiment score to df_news
# ----> 2 sia = SentimentIntensityAnalyzer()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nltk/sentiment/vader.py in __init__(self, lexicon_file)
#     338         lexicon_file="sentiment/vader_lexicon.zip/vader_lexicon/vader_lexicon.txt",
#     339     ):
# --> 340         self.lexicon_file = nltk.data.load(lexicon_file)
#     341         self.lexicon = self.make_lex_dict()
#     342         self.constants = VaderConstants()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     748
#     749     # Load the resource.
# --> 750     opened_resource = _open(resource_url)
#     751
#     752     if format == "raw":
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nltk/data.py in _open(resource_url)
#     874
#     875     if protocol is None or protocol.lower() == "nltk":
# --> 876         return find(path_, path + [""]).open()
#     877     elif protocol.lower() == "file":
#     878         # urllib might not use mode='rb', so handle this one ourselves:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/nltk/data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource vader_lexicon not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('vader_lexicon')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load sentiment/vader_lexicon.zip/vader_lexicon/vader_lexicon.txt
#
#   Searched in:
#     - '/Users/amanda/nltk_data'
#     - '/Library/Frameworks/Python.framework/Versions/3.8/nltk_data'
#     - '/Library/Frameworks/Python.framework/Versions/3.8/share/nltk_data'
#     - '/Library/Frameworks/Python.framework/Versions/3.8/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %%
ndf['Compound'] = [sia.polarity_scores(v)['compound'] for v in ndf['News']]
ndf['Negative'] = [sia.polarity_scores(v)['neg'] for v in ndf['News']]
ndf['Neutral'] = [sia.polarity_scores(v)['neu'] for v in ndf['News']]
ndf['Positive'] = [sia.polarity_scores(v)['pos'] for v in ndf['News']]
ndf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d1/0b_ckbv94b76520jr7j7ydzw0000gn/T/ipykernel_13346/2716469590.py in <module>
# ----> 1 ndf['Compound'] = [sia.polarity_scores(v)['compound'] for v in ndf['News']]
#       2 ndf['Negative'] = [sia.polarity_scores(v)['neg'] for v in ndf['News']]
#       3 ndf['Neutral'] = [sia.polarity_scores(v)['neu'] for v in ndf['News']]
#       4 ndf['Positive'] = [sia.polarity_scores(v)['pos'] for v in ndf['News']]
#       5 ndf
#
# /var/folders/d1/0b_ckbv94b76520jr7j7ydzw0000gn/T/ipykernel_13346/2716469590.py in <listcomp>(.0)
# ----> 1 ndf['Compound'] = [sia.polarity_scores(v)['compound'] for v in ndf['News']]
#       2 ndf['Negative'] = [sia.polarity_scores(v)['neg'] for v in ndf['News']]
#       3 ndf['Neutral'] = [sia.polarity_scores(v)['neu'] for v in ndf['News']]
#       4 ndf['Positive'] = [sia.polarity_scores(v)['pos'] for v in ndf['News']]
#       5 ndf
#
# NameError: name 'sia' is not defined

# %% [markdown]
# ## Merge the Historical and Textual Data

# %%
df_merge = pd.merge(hisdf, ndf, how='inner', on='Date')
df_merge

# %% [markdown]
# ## Create Dataset for Model Training

# %%
dfmerge1 = df_merge[['Close','Subjectivity', 'Polarity', 'Compound', 'Negative', 'Neutral', 'Positive']]
dfmerge1

# %% [markdown]
# ## Data Normalization

# %%
scaler = MinMaxScaler()

df = pd.DataFrame(scaler.fit_transform(dfmerge1))
df.columns = dfmerge1.columns
df.index = dfmerge1.index
df.head()

# %%
X=df.drop('Close',axis=1)
X

# %%
Y=df['Close']
Y

# %% [markdown]
# ## Split the Dataset into Train & Test Data

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state = 0)
x_train.shape

# %%
x_train[:10]

# %% [markdown]
# ## RandomForestRegressor Model

# %%
rf = RandomForestRegressor()
rf.fit(x_train, y_train)
prediction=rf.predict(x_test)
print(prediction[:10])
print(y_test[:10])
print('Mean Squared error: ',mean_squared_error(prediction,y_test))

# %% [markdown]
# ## DecisionTreeRegressor Model

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
predictions = dtr.predict(x_test)
print(predictions[:10])
print(y_test[:10])
print('Mean Squared error: ',mean_squared_error(predictions,y_test))

# %% [markdown]
# ## AdaBoostRegressor Model

# %%
adb = AdaBoostRegressor()
adb.fit(x_train, y_train)
predictions = adb.predict(x_test)
print(mean_squared_error(predictions, y_test))

# %% [markdown]
# ## XGBRegressor Model

# %%
xgb = xgboost.XGBRegressor()
xgb.fit(x_train, y_train)
predictions = xgb.predict(x_test)
print(mean_squared_error(predictions, y_test))
